# %%
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import  linear_model
from pandas.tools.plotting import scatter_matrix
from sklearn.metrics import r2_score

# %%
df_data = pd.read_csv('train.csv')
# df_data.as_matrix()
# X = df_data[:,0]

# %%
#df_data.columns

# %%
df = df_data.drop('Id', axis=1)
df = df.drop('PoolQC', axis=1)
df = df.drop('MiscFeature', axis=1)
df = df.drop('YrSold', axis=1)
df = df.drop('Street', axis=1)
df = df.drop('Alley', axis=1)
df = df.drop('Utilities', axis=1)
df = df.drop('LandContour', axis=1)
df = df.drop('LandSlope', axis=1)
df = df.drop('Condition2', axis=1)
df = df.drop('Condition1', axis=1)
df = df.drop('Neighborhood', axis=1)

# %%
#df.isnull().sum()
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea LotShape LotConfig BldgType  \
# 0             60       RL         65.0     8450      Reg    Inside     1Fam
# 1             20       RL         80.0     9600      Reg       FR2     1Fam
# 2             60       RL         68.0    11250      IR1    Inside     1Fam
# 3             70       RL         60.0     9550      IR1    Corner     1Fam
# 4             60       RL         84.0    14260      IR1       FR2     1Fam
# 5             50       RL         85.0    14115      IR1    Inside     1Fam
# 6             20       RL         75.0    10084      Reg    Inside     1Fam
# 7             60       RL          NaN    10382      IR1    Corner     1Fam
# 8             50       RM         51.0     6120      Reg    Inside     1Fam
# 9            190       RL         50.0     7420      Reg    Corner   2fmCon
# 10            20       RL         70.0    11200      Reg    Inside     1Fam
# ...

# %%
#df.columns

# %%
df['Fence'].value_counts()
#df['Neighborhood'].describe()
# KEEP=3SsnPorch,ScreenPorch,PoolArea,MiscVal,LotShape
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
#df = pd.get_dummies(df)
#df.head()
df.fillna(1, inplace=True)
df = pd.get_dummies(df)
df.isnull().sum()
# Out:
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# YearBuilt                0
# YearRemodAdd             0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageYrBlt              0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
#                         ..
# GarageQual_TA            0
# GarageCond_1             0
# GarageCond_Ex            0
# ...

# %%
bins = [0, 1950, 1975, 2000, 2025]
group_names = ['1', '2', '3', '4']
yb = pd.cut(df['YearBuilt'], bins, labels=group_names)
df['YearBuilt'] = yb

# %%
df['YearRemodAdd'].value_counts().sort_index()
# Out:
# 1950    178
# 1951      4
# 1952      5
# 1953     10
# 1954     14
# 1955      9
# 1956     10
# 1957      9
# 1958     15
# 1959     18
# 1960     12
# 1961      8
# 1962     14
# 1963     13
# 1964     11
# 1965     19
# 1966     15
# 1967     12
# 1968     17
# 1969     14
# 1970     26
# 1971     18
# 1972     20
# 1973     11
# 1974      7
# 1975     10
# 1976     30
# 1977     25
# 1978     16
# 1979     10
#        ...
# 1981      8
# 1982      7
# 1983      5
# 1984      7
# 1985      9
# 1986      5
# 1987     10
# 1988      9
# 1989     11
# 1990     15
# 1991     14
# 1992     17
# 1993     19
# 1994     22
# 1995     31
# 1996     36
# 1997     25
# 1998     36
# 1999     30
# 2000     55
# 2001     21
# 2002     48
# 2003     51
# 2004     62
# 2005     73
# 2006     97
# 2007     76
# 2008     40
# 2009     23
# 2010      6
# Name: YearRemodAdd, Length: 61, dtype: int64

# %%
bins = [1949,1975,2000,2010]
standard = [1,2,3]
remod = pd.cut(df['YearRemodAdd'], bins, labels=standard)
df['YearRemodAdd']=remod

# %%
df.isnull().sum()
# Out:
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# YearBuilt                0
# YearRemodAdd             0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageYrBlt              0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
#                         ..
# GarageQual_TA            0
# GarageCond_1             0
# GarageCond_Ex            0
# ...

# %%
x = df.drop('SalePrice', axis=1)
y = df['SalePrice']

# %%
regr = linear_model.LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_data, regr.predict(x_data))
print(r2)
# Out:
# 0.901135331467
